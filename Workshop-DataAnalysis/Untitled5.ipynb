# %%
# import the pandas and numpy library..
import numpy as np 
import pandas as pd

# %%
# read the .csv file?
df=pd.read_csv('Salary_Data.csv')
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# To print the number of rows and columns?
df.shape
# Out:
# (6704, 6)

# %%
#  to print thr column names?
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
### pandas data cleaning:
- 1.isnull():
        - To check the null values are present in a dataframe.
- 2. notnull()L
        - to check the not null values
- 3.dropna():
        - to delete the null values.
- 4.fillna():
           - to give the any meaningful name in a null values a data.
- 5. replace():
            - to replace the data.
- 6. sort_values():
            - to sort the data
# Out:
# <>:2: SyntaxWarning: invalid decimal literal
# <>:2: SyntaxWarning: invalid decimal literal
# C:\Users\91798\AppData\Local\Temp\ipykernel_15068\3101885751.py:2: SyntaxWarning: invalid decimal literal
#   - 1.isnull():
#   Cell In[6], line 6
#     - 3.dropna():
#        ^
# SyntaxError: invalid decimal literal

# %%
# isnull():
df.isnull()
# Out:
#         Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0     False   False            False      False                False   False
# 1     False   False            False      False                False   False
# 2     False   False            False      False                False   False
# 3     False   False            False      False                False   False
# 4     False   False            False      False                False   False
# ...     ...     ...              ...        ...                  ...     ...
# 6699  False   False            False      False                False   False
# 6700  False   False            False      False                False   False
# 6701  False   False            False      False                False   False
# 6702  False   False            False      False                False   False
# 6703  False   False            False      False                False   False
#
# [6704 rows x 6 columns]

# %%
# notnull?
df.notnull()
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0     True    True             True       True                 True    True
# 1     True    True             True       True                 True    True
# 2     True    True             True       True                 True    True
# 3     True    True             True       True                 True    True
# 4     True    True             True       True                 True    True
# ...    ...     ...              ...        ...                  ...     ...
# 6699  True    True             True       True                 True    True
# 6700  True    True             True       True                 True    True
# 6701  True    True             True       True                 True    True
# 6702  True    True             True       True                 True    True
# 6703  True    True             True       True                 True    True
#
# [6704 rows x 6 columns]

# %%
# fillna?
df.fillna('python')
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ...

# %%
# to count the number of null values in each column..
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
# dropna():
df.dropna()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# replace():
df.replace('Female','F')
# Out:
#        Age Gender    Education Level              Job Title  \
# 0     32.0   Male         Bachelor's      Software Engineer
# 1     28.0      F           Master's           Data Analyst
# 2     45.0   Male                PhD         Senior Manager
# 3     36.0      F         Bachelor's        Sales Associate
# 4     52.0   Male           Master's               Director
# ...    ...    ...                ...                    ...
# 6699  49.0      F                PhD  Director of Marketing
# 6700  32.0   Male        High School        Sales Associate
# 6701  30.0      F  Bachelor's Degree      Financial Manager
# 6702  46.0   Male    Master's Degree      Marketing Manager
# 6703  26.0      F        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# sort_values():
df.sort_values('Salary',ascending=False)
# Out:
#        Age  Gender    Education Level                 Job Title  \
# 83    52.0    Male                PhD  Chief Technology Officer
# 30    50.0    Male         Bachelor's                       CEO
# 5001  45.0    Male  Bachelor's Degree         Financial Manager
# 4306  51.0    Male                PhD            Data Scientist
# 4366  51.0    Male                PhD            Data Scientist
# ...    ...     ...                ...                       ...
# 172    NaN     NaN                NaN                       NaN
# 260    NaN     NaN                NaN                       NaN
# 3136  31.0    Male    Master's Degree       Full Stack Engineer
# 5247  26.0  Female  Bachelor's Degree                  Social M
# 6455  36.0    Male  Bachelor's Degree            Sales Director
#
#       Years of Experience    Salary
# 83                   24.0  250000.0
# 30                   25.0  250000.0
# 5001                 21.0  250000.0
# 4306                 24.0  240000.0
# ...

# %%
# To print the only job title as CEO...
df[df['Job Title'] == 'CEO']

# To print only the Male records..
df[df['Gender'] == 'Male']

# To print Female gender with Educational level PhD I
df[(df['Gender'] == 'Female') & (df['Education Level'] == 'PhD')]
# Out:
#        Age  Gender Education Level                         Job Title  \
# 28    43.0  Female             PhD                 Senior Consultant
# 124   44.0  Female             PhD                  Senior Scientist
# 146   42.0  Female             PhD             Senior Data Scientist
# 152   43.0  Female             PhD           Senior Product Designer
# 158   51.0  Female             PhD       Director of Human Resources
# ...    ...     ...             ...                               ...
# 6671  49.0  Female             PhD             Director of Marketing
# 6677  36.0  Female             PhD  Senior Product Marketing Manager
# 6685  49.0  Female             PhD  Senior Product Marketing Manager
# 6691  36.0  Female             PhD                 Marketing Manager
# 6699  49.0  Female             PhD             Director of Marketing
#
#       Years of Experience    Salary
# 28                   15.0  140000.0
# 124                  16.0  140000.0
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Software Engineer             518
# Data Scientist                453
# Software Engineer Manager     376
# Data Analyst                  363
# Senior Project Engineer       318
#                              ...
# Account Manager                 1
# Help Desk Analyst               1
# Senior Training Specialist      1
# Junior Web Designer             1
# Supply Chain Analyst            1
# Name: Job Title, Length: 193, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      3674
# Female    3014
# Other       14
# Name: Gender, dtype: int64

# %%
### grouping():
- gropuby()
- get_group()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ### grouping():
# ----> 2 - gropuby()
#       3 - get_group()
#
# NameError: name 'gropuby' is not defined

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# apply grouping functionss...
g=df.groupby('Education Level')
g.get_group('High School')
# Out:
#        Age  Gender Education Level                    Job Title  \
# 2378  53.0   Other     High School      Senior Project Engineer
# 2385  25.0   Other     High School          Full Stack Engineer
# 2395  30.0    Male     High School      Senior Project Engineer
# 2403  28.0    Male     High School           Back end Developer
# 2411  24.0  Female     High School      Senior Project Engineer
# ...    ...     ...             ...                          ...
# 6686  32.0    Male     High School  Junior Sales Representative
# 6689  26.0  Female     High School              Sales Associate
# 6694  27.0    Male     High School    Digital Marketing Manager
# 6700  32.0    Male     High School              Sales Associate
# 6703  26.0  Female     High School              Sales Executive
#
#       Years of Experience    Salary
# 2378                 31.0  166109.0
# 2385                  2.0   69032.0
# 2395                 11.0  103947.0
# 2403                  7.0   95845.0
# ...

# %% [markdown]
# #### statistics

# %%
df.mean()
# Out:
# C:\Users\91798\AppData\Local\Temp\ipykernel_15068\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Age                        33.620859
# Years of Experience         8.094687
# Salary                 115326.964771
# dtype: float64

# %%
df.mode()
# Out:
#     Age Gender    Education Level          Job Title  Years of Experience  \
# 0  27.0   Male  Bachelor's Degree  Software Engineer                  2.0
#
#      Salary
# 0  140000.0

# %%
df['Salary'].max()
# Out:
# 250000.0

# %%
df['Salary'].min()
# Out:
# 350.0
